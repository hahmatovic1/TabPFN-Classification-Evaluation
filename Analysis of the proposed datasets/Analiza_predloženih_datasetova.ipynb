# %% [markdown]
# # Breast Cancer dataset

# %%
#Učitavanje datoteke
import pandas as pd
df = pd.read_csv("data_Breast_Cancer.csv")
#Ukalananje poslednje kolone
df = df.drop(columns=["Unnamed: 32"])
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=df)
plt.title('Distribucija Dijagnoza (Maligno vs Benigno)')
plt.xlabel('Dijagnoza')
plt.ylabel('Broj uzoraka')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Atributi koji se prikazuju
attributes = [
    'radius_mean',
    'perimeter_mean',
    'area_mean',
    'concavity_mean',
    'concave points_mean'
]

# Postavke dizajna
sns.set(style="white", font_scale=1.2)
plt.figure(figsize=(15, 10))

# Prilagođena paleta boja
custom_palette = {"B": "skyblue", "M": "lightcoral"}


for i, attr in enumerate(attributes, 1):
    plt.subplot(2, 3, i)
    sns.histplot(
        data=df, x=attr, hue='diagnosis',
        bins=30, stat='count', common_norm=False,
        palette=custom_palette, alpha=0.6
    )
    plt.title(f'Distribucija atributa: {attr}', fontsize=14, weight='bold')
    plt.xlabel(attr)
    plt.ylabel('Broj uzoraka')
    plt.grid(False)

plt.tight_layout()
plt.legend(title='Dijagnoza', labels=['Benigno', 'Maligno'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Prima Indian Diabetes Dataset

# %%
#Učitavanje datoteke
import pandas as pd
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))
ax = sns.countplot(x='Outcome', data=df)
plt.title('Distribucija Dijagnoza (Dijabetes vs Bez dijabetesa)')
plt.xlabel('Dijagnoza')
plt.ylabel('Broj uzoraka')
plt.xticks([0, 1], ['Bez dijabetesa', 'Sa dijabetesom'])
# Dodavanje procenta iznad stupaca
total = len(df)
for p in ax.patches:
    count = int(p.get_height())
    percentage = 100 * count / total
    ax.annotate(f'{count} ({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Atributi koje želimo prikazati
attributes = [
    'Glucose',
    'BloodPressure',
    'BMI',
    'Insulin',
    'Age'
]

# Postavke dizajna
sns.set(style="white", font_scale=1.2)
plt.figure(figsize=(15, 10))

# Prilagođena paleta boja
custom_palette = {0: "skyblue", 1: "salmon"}

for i, attr in enumerate(attributes, 1):
    plt.subplot(2, 3, i)
    sns.histplot(
        data=df, x=attr, hue='Outcome',
        bins=30, stat='count', common_norm=False,
        palette=custom_palette, alpha=0.6
    )
    plt.title(f'Distribucija atributa: {attr}', fontsize=14, weight='bold')
    plt.xlabel(attr)
    plt.ylabel('Broj uzoraka')
    plt.grid(False)

plt.tight_layout()
plt.legend(title='Dijagnoza', labels=['Bez dijabetesa', 'Sa dijabetesom'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import numpy as np

# Kolone koje sadrže implicitne nedostajuće vrijednosti
cols_with_missing = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Zamjena nula sa NaN
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# Popunjavanje NaN vrijednosti medianom, bez inplace
for col in cols_with_missing:
    df[col] = df[col].fillna(df[col].median())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Atributi koje želimo prikazati
attributes = [
    'Glucose',
    'BloodPressure',
    'BMI',
    'Insulin',
    'Age'
]

# Postavke dizajna
sns.set(style="white", font_scale=1.2)
plt.figure(figsize=(15, 10))

# Prilagođena paleta boja
custom_palette = {0: "skyblue", 1: "salmon"}

for i, attr in enumerate(attributes, 1):
    plt.subplot(2, 3, i)
    sns.histplot(
        data=df, x=attr, hue='Outcome',
        bins=30, stat='count', common_norm=False,
        palette=custom_palette, alpha=0.6
    )
    plt.title(f'Distribucija atributa: {attr}', fontsize=14, weight='bold')
    plt.xlabel(attr)
    plt.ylabel('Broj uzoraka')
    plt.grid(False)

plt.tight_layout()
plt.legend(title='Dijagnoza', labels=['Bez dijabetesa', 'Sa dijabetesom'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Wine Quality dataset

# %%
#Učitavanje datoteke
import pandas as pd
df = pd.read_csv("winequalityN.csv")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
ax = sns.countplot(x='quality', hue='quality', data=df, palette='Set3', legend=False)
plt.title('Distribucija klasa – Ocjena kvaliteta vina')
plt.xlabel('Ocjena kvaliteta (quality)')
plt.ylabel('Broj uzoraka')

# Dodavanje procenta iznad svake kolone
total = len(df)
for p in ax.patches:
    count = int(p.get_height())
    percentage = 100 * count / total
    ax.annotate(f'{count} ({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Atributi koje želimo prikazati (prilagodi po želji)
attributes = [
    'alcohol',
    'volatile acidity',
    'sulphates',
    'citric acid',
    'density'
]


# Postavke dizajna
sns.set(style="white", font_scale=1.2)
plt.figure(figsize=(16, 10))

# Boje za višeklasa klasifikaciju
palette = sns.color_palette("tab10", n_colors=df['quality'].nunique())

for i, attr in enumerate(attributes, 1):
    plt.subplot(2, 3, i)
    sns.histplot(
        data=df, x=attr, hue='quality',
        bins=30, stat='count', common_norm=False,
        palette=palette, alpha=0.7,
        multiple='stack'
    )
    plt.title(f'Distribucija atributa: {attr}', fontsize=14, weight='bold')
    plt.xlabel(attr)
    plt.ylabel('Broj uzoraka')
    plt.grid(False)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Grupisanje kvaliteta u tri klase
def map_quality(q):
    if q in [3, 4]:
        return 'Nizak kvalitet'
    elif q in [5,6]:
        return 'Srednji kvalitet'
    else:
        return 'Visok kvalitet'

# Nova kolona
df['quality_grouped'] = df['quality'].apply(map_quality)

# 2. Prikaz broja uzoraka po novim klasama
class_counts = df['quality_grouped'].value_counts().sort_index()
total = len(df)

print("Distribucija po grupama:")
for k, v in class_counts.items():
    print(f"{k}: {v} uzoraka ({100 * v / total:.1f}%)")

# 3. Grafički prikaz raspodjele
plt.figure(figsize=(7, 5))
ax = sns.countplot(x='quality_grouped', data=df, palette='Set2')
plt.title('Distribucija kvaliteta vina (3 klase)')
plt.xlabel('Kategorija kvaliteta')
plt.ylabel('Broj uzoraka')

# Dodavanje brojeva i procenata iznad stubaca
for p in ax.patches:
    count = int(p.get_height())
    percentage = 100 * count / total
    ax.annotate(f'{count} ({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# Distribucija po grupama:
# Nizak kvalitet: 246 uzoraka (3.8%)
# Srednji kvalitet: 4974 uzoraka (76.6%)
# Visok kvalitet: 1277 uzoraka (19.7%)
# /tmp/ipython-input-6-3990222462.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='quality_grouped', data=df, palette='Set2')
